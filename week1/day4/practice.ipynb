# %% [markdown]
# #### DataFrame
#
# * Creating DataFrames from dictionaries
# * Creating DataFrames from lists
# * Understanding rows and columns
#
# ---
#
# ### 3. Reading Data
#
# * `pd.read_csv()`
# * `pd.read_excel()`
# * Viewing datasets
#
# ```python
# df.head()
# df.tail()
# df.sample()
# ```
#
# ---
#
# ### 4. Dataset Information
#
# ```python
# df.shape
# df.columns
# df.info()
# df.describe()
# ```
#
# Understand:
#
# * Number of rows and columns
# * Data types
# * Missing values
# * Statistical summary
#
# ---
#
# ### 5. Selecting Data
#
# #### Single Column
#
# ```python
# df["column"]
# ```
#
# #### Multiple Columns
#
# ```python
# df[["col1", "col2"]]
# ```
#
# #### Rows
#
# ```python
# df.loc[]
# df.iloc[]
# ```
#
# ---
#
# ### 6. Filtering Data
#
# Examples:
#
# ```python
# df[df["Age"] > 25]
# df[df["Salary"] > 50000]
# ```
#
# Combining conditions:
#
# ```python
# (df["Age"] > 25) & (df["Salary"] > 50000)
# ```
#
# ---
#
# ### 7. Sorting Data
#
# ```python
# df.sort_values()
# ```
#
# Sort by:
#
# * Single column
# * Multiple columns
# * Ascending/Descending
#
# ---
#
# ### 8. Basic Aggregations
#
# ```python
# df["Salary"].mean()
# df["Salary"].sum()
# df["Salary"].max()
# df["Salary"].min()
# df["Salary"].count()
# ```
#
# ---
#
# ### 9. Handling Missing Values
#
# ```python
# df.isnull()
# df.isnull().sum()
# df.dropna()
# df.fillna()
# ```
#
# ---
#
# ### 10. Exporting Data
#
# ```python
# df.to_csv()
# ```
#
# Save processed datasets.
#
# ---

# %%
import pandas as pd

# %%
l = [1, 2, 3, 4, 5]
l2 = [1, 2, 3, 4, 5]
s = pd.Series(l)
s2 = pd.Series(l2)
print(s)
print(s2)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# Creating a Series with custom indices

s3 = pd.Series(l, index=['a', 'b', 'c', 'd', 'e'])
print(s3)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
data = {
    'name': ['Alice', 'Bob', 'Charlie'],
    'age': [25, 30, 35],
    'city': ['New York', 'Los Angeles', 'Chicago']
}
df = pd.DataFrame(data)

# %%
df = pd.read_csv("data/sample.csv")

# %%
df.head()
df.tail()
df.sample(5)

df.shape
df.columns
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  1000 non-null   int64
#  1   age                                 1000 non-null   int64
#  2   alcohol_consumption_per_week        1000 non-null   int64
#  3   physical_activity_minutes_per_week  1000 non-null   int64
#  4   diet_score                          1000 non-null   float64
#  5   sleep_hours_per_day                 1000 non-null   float64
#  6   screen_time_hours_per_day           1000 non-null   float64
#  7   bmi                                 1000 non-null   float64
#  8   waist_to_hip_ratio                  1000 non-null   float64
#  9   systolic_bp                         1000 non-null   int64
#  10  diastolic_bp                        1000 non-null   int64
#  11  heart_rate                          1000 non-null   int64
#  12  cholesterol_total                   1000 non-null   int64
#  13  hdl_cholesterol                     1000 non-null   int64
#  14  ldl_cholesterol                     1000 non-null   int64
#  15  triglycerides                       1000 non-null   int64
#  16  gender                              1000 non-null   object
#  17  ethnicity                           1000 non-null   object
#  18  education_level                     1000 non-null   object
#  19  income_level                        1000 non-null   object
#  20  smoking_status                      1000 non-null   object
#  21  employment_status                   1000 non-null   object
#  22  family_history_diabetes             1000 non-null   int64
#  23  hypertension_history                1000 non-null   int64
#  24  cardiovascular_history              1000 non-null   int64
#  25  diagnosed_diabetes                  1000 non-null   float64
# dtypes: float64(6), int64(14), object(6)
# memory usage: 203.3+ KB
#                 id         age  alcohol_consumption_per_week  \
# count  1000.000000  1000.00000                   1000.000000
# mean    499.500000    49.88300                      2.022000
# std     288.819436    11.77038                      1.004253
# min       0.000000    19.00000                      1.000000
# 25%     249.750000    42.00000                      1.000000
# 50%     499.500000    50.00000                      2.000000
# 75%     749.250000    58.00000                      3.000000
# max     999.000000    84.00000                      6.000000
#
#        physical_activity_minutes_per_week   diet_score  sleep_hours_per_day  \
# count                         1000.000000  1000.000000          1000.000000
# mean                            82.135000     5.917600             7.015600
# std                             56.690074     1.457599             0.908605
# min                              4.000000     1.700000             3.800000
# 25%                             48.750000     4.900000             6.400000
# 50%                             70.000000     5.900000             7.000000
# 75%                             97.250000     6.900000             7.600000
# max                            551.000000     9.700000             9.900000
#
#        screen_time_hours_per_day          bmi  waist_to_hip_ratio  \
# count                1000.000000  1000.000000         1000.000000
# mean                    6.022400    25.809800            0.857530
# std                     1.988928     2.852167            0.038011
# min                     1.200000    17.600000            0.740000
# 25%                     4.500000    23.800000            0.830000
# 50%                     6.000000    25.800000            0.860000
# 75%                     7.425000    27.700000            0.880000
# max                    12.500000    34.100000            0.970000
#
#        systolic_bp  diastolic_bp   heart_rate  cholesterol_total  \
# count  1000.000000   1000.000000  1000.000000        1000.000000
# mean    116.161000     75.619000    69.896000         186.784000
# std      10.694459      6.763696     7.049885          16.723008
# min      91.000000     57.000000    49.000000         144.000000
# 25%     108.000000     71.000000    65.000000         175.000000
# 50%     117.000000     76.000000    70.000000         187.000000
# 75%     124.000000     80.000000    75.000000         199.000000
# max     146.000000     96.000000    89.000000         235.000000
#
#        hdl_cholesterol  ldl_cholesterol  triglycerides  \
# count      1000.000000      1000.000000      1000.0000
# mean         53.857000       102.595000       121.9920
# std           8.202428        18.688666        24.0883
# min          29.000000        52.000000        38.0000
# 25%          48.000000        89.000000       107.0000
# 50%          54.000000       102.000000       122.0000
# 75%          59.000000       116.000000       137.0000
# max          80.000000       165.000000       226.0000
#
#        family_history_diabetes  hypertension_history  cardiovascular_history  \
# count              1000.000000            1000.00000             1000.000000
# mean                  0.151000               0.17700                0.040000
# std                   0.358228               0.38186                0.196057
# min                   0.000000               0.00000                0.000000
# 25%                   0.000000               0.00000                0.000000
# 50%                   0.000000               0.00000                0.000000
# 75%                   0.000000               0.00000                0.000000
# max                   1.000000               1.00000                1.000000
#
#        diagnosed_diabetes
# count         1000.000000
# mean             0.595000
# std              0.491138
# min              0.000000
# 25%              0.000000
# 50%              1.000000
# 75%              1.000000
# max              1.000000

# %%
df["age"]

df["bmi"]

df[["age", "bmi", "systolic_bp"]]
# Out:
#      age   bmi  systolic_bp
# 0     31  33.4          112
# 1     50  23.8          120
# 2     32  24.1           95
# 3     54  26.6          121
# 4     54  28.8          108
# ..   ...   ...          ...
# 995   61  23.7          121
# 996   54  22.7          112
# 997   22  28.5          115
# 998   34  27.5          114
# 999   42  21.3          110
#
# [1000 rows x 3 columns]

# %%
a.age
# Out:
# 0      31
# 1      50
# 2      32
# 3      54
# 4      54
#        ..
# 995    61
# 996    54
# 997    22
# 998    34
# 999    42
# Name: age, Length: 1000, dtype: int64

# %%
df.loc[0]

df.iloc[0]

df.iloc[0:10]
# Out:
#    id  age  alcohol_consumption_per_week  physical_activity_minutes_per_week  \
# 0   0   31                             1                                  45
# 1   1   50                             2                                  73
# 2   2   32                             3                                 158
# 3   3   54                             3                                  77
# 4   4   54                             1                                  55
# 5   5   42                             1                                 100
# 6   6   41                             2                                 148
# 7   7   51                             3                                 102
# 8   8   34                             2                                  44
# 9   9   44                             1                                  36
#
#    diet_score  sleep_hours_per_day  screen_time_hours_per_day   bmi  \
# 0         7.7                  6.8                        6.1  33.4
# 1         5.7                  6.5                        5.8  23.8
# 2         8.5                  7.4                        9.1  24.1
# 3         4.6                  7.0                        9.2  26.6
# 4         5.7                  6.2                        5.1  28.8
# 5         4.4                  6.4                        5.3  25.5
# 6         3.4                  5.6                        3.7  27.9
# 7         4.0                  7.3                        5.5  27.1
# 8         2.7                  7.0                        7.9  22.6
# 9         5.8                  5.7                        6.6  29.3
#
#    waist_to_hip_ratio  systolic_bp  ...  gender  ethnicity  education_level  \
# 0                0.93          112  ...  Female   Hispanic       Highschool
# 1                0.83          120  ...  Female      White       Highschool
# 2                0.83           95  ...    Male   Hispanic       Highschool
# 3                0.83          121  ...  Female      White       Highschool
# 4                0.90          108  ...    Male      White       Highschool
# 5                0.84          111  ...  Female      White       Highschool
# 6                0.89          130  ...  Female      White         Graduate
# 7                0.83          125  ...    Male      Asian       Highschool
# 8                0.81          120  ...    Male      White       Highschool
# 9                0.88          110  ...    Male   Hispanic       Highschool
#
#    income_level  smoking_status  employment_status family_history_diabetes  \
# 0  Lower-Middle         Current           Employed                       0
# 1  Upper-Middle           Never           Employed                       0
# 2  Lower-Middle           Never            Retired                       0
# 3  Lower-Middle         Current           Employed                       0
# 4  Upper-Middle           Never            Retired                       0
# 5  Lower-Middle           Never            Retired                       0
# 6  Lower-Middle         Current           Employed                       0
# 7           Low           Never           Employed                       1
# 8  Lower-Middle           Never           Employed                       0
# 9        Middle           Never           Employed                       1
#
#   hypertension_history cardiovascular_history diagnosed_diabetes
# 0                    0                      0                1.0
# 1                    0                      0                1.0
# 2                    0                      0                0.0
# 3                    1                      0                1.0
# 4                    1                      0                1.0
# 5                    0                      0                0.0
# 6                    0                      0                1.0
# 7                    0                      0                1.0
# 8                    0                      0                0.0
# 9                    0                      0                1.0
#
# [10 rows x 26 columns]

# %%
a[a['age'] > 30]
# Out:
#       id  age  alcohol_consumption_per_week  \
# 0      0   31                             1
# 1      1   50                             2
# 2      2   32                             3
# 3      3   54                             3
# 4      4   54                             1
# ..   ...  ...                           ...
# 994  994   54                             4
# 995  995   61                             1
# 996  996   54                             1
# 998  998   34                             1
# 999  999   42                             2
#
#      physical_activity_minutes_per_week  diet_score  sleep_hours_per_day  \
# 0                                    45         7.7                  6.8
# 1                                    73         5.7                  6.5
# 2                                   158         8.5                  7.4
# 3                                    77         4.6                  7.0
# 4                                    55         5.7                  6.2
# ..                                  ...         ...                  ...
# 994                                  46         8.1                  7.7
# 995                                  32         3.7                  5.4
# 996                                  28         6.2                  7.9
# 998                                  98         4.8                  7.5
# 999                                  38         6.1                  7.1
#
#      screen_time_hours_per_day   bmi  waist_to_hip_ratio  systolic_bp  ...  \
# 0                          6.1  33.4                0.93          112  ...
# 1                          5.8  23.8                0.83          120  ...
# 2                          9.1  24.1                0.83           95  ...
# 3                          9.2  26.6                0.83          121  ...
# 4                          5.1  28.8                0.90          108  ...
# ..                         ...   ...                 ...          ...  ...
# 994                        7.1  29.9                0.91          115  ...
# 995                        4.4  23.7                0.81          121  ...
# 996                        6.3  22.7                0.81          112  ...
# 998                        7.8  27.5                0.88          114  ...
# 999                        5.3  21.3                0.79          110  ...
#
#      gender  ethnicity  education_level  income_level  smoking_status  \
# 0    Female   Hispanic       Highschool  Lower-Middle         Current
# 1    Female      White       Highschool  Upper-Middle           Never
# 2      Male   Hispanic       Highschool  Lower-Middle           Never
# 3    Female      White       Highschool  Lower-Middle         Current
# 4      Male      White       Highschool  Upper-Middle           Never
# ..      ...        ...              ...           ...             ...
# 994    Male      White       Highschool        Middle          Former
# 995  Female      White       Highschool  Upper-Middle           Never
# 996    Male   Hispanic       Highschool        Middle           Never
# 998  Female      Black       Highschool        Middle         Current
# 999  Female      White         Graduate  Lower-Middle           Never
#
#      employment_status family_history_diabetes hypertension_history  \
# 0             Employed                       0                    0
# 1             Employed                       0                    0
# 2              Retired                       0                    0
# 3             Employed                       0                    1
# 4              Retired                       0                    1
# ..                 ...                     ...                  ...
# 994           Employed                       0                    0
# 995           Employed                       0                    0
# 996            Retired                       1                    0
# 998           Employed                       0                    0
# 999            Retired                       0                    0
#
#     cardiovascular_history diagnosed_diabetes
# 0                        0                1.0
# 1                        0                1.0
# 2                        0                0.0
# 3                        0                1.0
# 4                        0                1.0
# ..                     ...                ...
# 994                      0                0.0
# 995                      0                1.0
# 996                      0                0.0
# 998                      0                1.0
# 999                      0                1.0
#
# [946 rows x 26 columns]

# %%
df[df["age"] > 50]
# Out:
#       id  age  alcohol_consumption_per_week  \
# 3      3   54                             3
# 4      4   54                             1
# 7      7   51                             3
# 11    11   54                             2
# 12    12   63                             2
# ..   ...  ...                           ...
# 991  991   69                             2
# 993  993   58                             2
# 994  994   54                             4
# 995  995   61                             1
# 996  996   54                             1
#
#      physical_activity_minutes_per_week  diet_score  sleep_hours_per_day  \
# 3                                    77         4.6                  7.0
# 4                                    55         5.7                  6.2
# 7                                   102         4.0                  7.3
# 11                                   58         6.2                  7.7
# 12                                   44         8.0                  6.0
# ..                                  ...         ...                  ...
# 991                                 261         3.3                  8.9
# 993                                 189         4.9                  8.6
# 994                                  46         8.1                  7.7
# 995                                  32         3.7                  5.4
# 996                                  28         6.2                  7.9
#
#      screen_time_hours_per_day   bmi  waist_to_hip_ratio  systolic_bp  ...  \
# 3                          9.2  26.6                0.83          121  ...
# 4                          5.1  28.8                0.90          108  ...
# 7                          5.5  27.1                0.83          125  ...
# 11                         7.2  23.3                0.81          124  ...
# 12                         6.8  26.6                0.88          119  ...
# ..                         ...   ...                 ...          ...  ...
# 991                        8.4  23.7                0.85          124  ...
# 993                        7.6  26.7                0.87          117  ...
# 994                        7.1  29.9                0.91          115  ...
# 995                        4.4  23.7                0.81          121  ...
# 996                        6.3  22.7                0.81          112  ...
#
#      gender  ethnicity  education_level  income_level  smoking_status  \
# 3    Female      White       Highschool  Lower-Middle         Current
# 4      Male      White       Highschool  Upper-Middle           Never
# 7      Male      Asian       Highschool           Low           Never
# 11     Male      White       Highschool           Low           Never
# 12   Female      White     Postgraduate        Middle           Never
# ..      ...        ...              ...           ...             ...
# 991  Female      Asian         Graduate  Upper-Middle           Never
# 993  Female      White         Graduate  Lower-Middle           Never
# 994    Male      White       Highschool        Middle          Former
# 995  Female      White       Highschool  Upper-Middle           Never
# 996    Male   Hispanic       Highschool        Middle           Never
#
#      employment_status family_history_diabetes hypertension_history  \
# 3             Employed                       0                    1
# 4              Retired                       0                    1
# 7             Employed                       1                    0
# 11            Employed                       0                    0
# 12            Employed                       1                    0
# ..                 ...                     ...                  ...
# 991           Employed                       0                    1
# 993           Employed                       0                    0
# 994           Employed                       0                    0
# 995           Employed                       0                    0
# 996            Retired                       1                    0
#
#     cardiovascular_history diagnosed_diabetes
# 3                        0                1.0
# 4                        0                1.0
# 7                        0                1.0
# 11                       0                0.0
# 12                       0                1.0
# ..                     ...                ...
# 991                      0                0.0
# 993                      0                1.0
# 994                      0                0.0
# 995                      0                1.0
# 996                      0                0.0
#
# [491 rows x 26 columns]

# %%
df[
    (df["family_history_diabetes"] == 1) &
    (df["diagnosed_diabetes"] == 1)
]
# Out:
#       id  age  alcohol_consumption_per_week  \
# 7      7   51                             3
# 9      9   44                             1
# 12    12   63                             2
# 18    18   43                             2
# 22    22   45                             4
# ..   ...  ...                           ...
# 944  944   48                             1
# 953  953   56                             3
# 960  960   26                             4
# 972  972   29                             2
# 985  985   38                             3
#
#      physical_activity_minutes_per_week  diet_score  sleep_hours_per_day  \
# 7                                   102         4.0                  7.3
# 9                                    36         5.8                  5.7
# 12                                   44         8.0                  6.0
# 18                                   53         4.1                  7.4
# 22                                   94         5.4                  6.6
# ..                                  ...         ...                  ...
# 944                                  32         3.9                  8.1
# 953                                  64         7.7                  5.0
# 960                                 123         7.8                  5.5
# 972                                  62         2.3                  6.0
# 985                                  38         2.6                  5.8
#
#      screen_time_hours_per_day   bmi  waist_to_hip_ratio  systolic_bp  ...  \
# 7                          5.5  27.1                0.83          125  ...
# 9                          6.6  29.3                0.88          110  ...
# 12                         6.8  26.6                0.88          119  ...
# 18                         6.4  23.8                0.85          120  ...
# 22                         7.2  28.4                0.87          123  ...
# ..                         ...   ...                 ...          ...  ...
# 944                        8.7  27.6                0.83          132  ...
# 953                        9.5  25.3                0.88          115  ...
# 960                        7.8  27.7                0.87          109  ...
# 972                        4.9  30.4                0.90           99  ...
# 985                        7.1  26.7                0.85          107  ...
#
#      gender  ethnicity  education_level  income_level  smoking_status  \
# 7      Male      Asian       Highschool           Low           Never
# 9      Male   Hispanic       Highschool        Middle           Never
# 12   Female      White     Postgraduate        Middle           Never
# 18   Female      White       Highschool  Lower-Middle          Former
# 22   Female      White       Highschool        Middle          Former
# ..      ...        ...              ...           ...             ...
# 944  Female      Black       Highschool           Low           Never
# 953  Female      White       Highschool        Middle          Former
# 960  Female      White       Highschool  Lower-Middle          Former
# 972  Female      White       Highschool        Middle         Current
# 985  Female   Hispanic       Highschool        Middle          Former
#
#      employment_status family_history_diabetes hypertension_history  \
# 7             Employed                       1                    0
# 9             Employed                       1                    0
# 12            Employed                       1                    0
# 18             Retired                       1                    0
# 22            Employed                       1                    0
# ..                 ...                     ...                  ...
# 944           Employed                       1                    1
# 953           Employed                       1                    0
# 960           Employed                       1                    0
# 972           Employed                       1                    0
# 985           Employed                       1                    0
#
#     cardiovascular_history diagnosed_diabetes
# 7                        0                1.0
# 9                        0                1.0
# 12                       0                1.0
# 18                       0                1.0
# 22                       0                1.0
# ..                     ...                ...
# 944                      0                1.0
# 953                      0                1.0
# 960                      0                1.0
# 972                      0                1.0
# 985                      0                1.0
#
# [128 rows x 26 columns]

# %%
df["age"].mean()

df["bmi"].mean()

df["cholesterol_total"].max()

df["heart_rate"].min()

df["age"].median()

df["bmi"].std()
# Out:
# np.float64(2.852167389691359)

# %%
df.sort_values("age")

df.sort_values("bmi", ascending=False)

df.sort_values(
    ["age", "bmi"],
    ascending=False
)
# Out:
#       id  age  alcohol_consumption_per_week  \
# 132  132   84                             4
# 659  659   82                             2
# 850  850   81                             1
# 864  864   80                             3
# 267  267   80                             1
# ..   ...  ...                           ...
# 816  816   21                             1
# 309  309   20                             3
# 449  449   20                             2
# 31    31   20                             2
# 591  591   19                             1
#
#      physical_activity_minutes_per_week  diet_score  sleep_hours_per_day  \
# 132                                  55         2.8                  7.7
# 659                                  39         7.6                  7.0
# 850                                  64         4.1                  7.8
# 864                                 122         6.0                  6.9
# 267                                 112         9.2                  7.1
# ..                                  ...         ...                  ...
# 816                                  91         4.1                  7.7
# 309                                  23         5.5                  5.8
# 449                                  52         5.6                  6.7
# 31                                   59         7.7                  8.8
# 591                                 107         6.2                  7.8
#
#      screen_time_hours_per_day   bmi  waist_to_hip_ratio  systolic_bp  ...  \
# 132                        4.8  30.9                0.92          125  ...
# 659                        5.8  25.9                0.89          123  ...
# 850                        6.6  25.0                0.89          109  ...
# 864                        6.8  25.0                0.88          130  ...
# 267                        4.1  21.3                0.82          134  ...
# ..                         ...   ...                 ...          ...  ...
# 816                        4.1  24.5                0.84          108  ...
# 309                        3.7  27.3                0.88          109  ...
# 449                        7.9  21.3                0.76          103  ...
# 31                        10.1  20.8                0.85           98  ...
# 591                        7.6  22.3                0.77          100  ...
#
#      gender  ethnicity  education_level  income_level  smoking_status  \
# 132    Male      Other       Highschool  Upper-Middle           Never
# 659  Female      White     Postgraduate           Low          Former
# 850  Female   Hispanic       Highschool        Middle          Former
# 864  Female   Hispanic       Highschool  Lower-Middle          Former
# 267    Male      White     Postgraduate           Low           Never
# ..      ...        ...              ...           ...             ...
# 816  Female      White       Highschool        Middle          Former
# 309  Female      White       Highschool        Middle          Former
# 449  Female      White         Graduate  Upper-Middle           Never
# 31   Female   Hispanic       Highschool  Lower-Middle           Never
# 591  Female      Black         Graduate  Lower-Middle           Never
#
#      employment_status family_history_diabetes hypertension_history  \
# 132           Employed                       0                    0
# 659           Employed                       0                    1
# 850            Retired                       0                    1
# 864         Unemployed                       0                    0
# 267            Retired                       0                    0
# ..                 ...                     ...                  ...
# 816           Employed                       0                    0
# 309            Student                       0                    0
# 449           Employed                       0                    1
# 31             Retired                       1                    0
# 591           Employed                       0                    0
#
#     cardiovascular_history diagnosed_diabetes
# 132                      1                0.0
# 659                      0                1.0
# 850                      0                1.0
# 864                      0                0.0
# 267                      1                0.0
# ..                     ...                ...
# 816                      0                0.0
# 309                      0                1.0
# 449                      0                0.0
# 31                       0                1.0
# 591                      0                1.0
#
# [1000 rows x 26 columns]

# %%
df.isnull()

df.isnull().sum()

df.isnull().any()
# Out:
# id                                    False
# age                                   False
# alcohol_consumption_per_week          False
# physical_activity_minutes_per_week    False
# diet_score                            False
# sleep_hours_per_day                   False
# screen_time_hours_per_day             False
# bmi                                   False
# waist_to_hip_ratio                    False
# systolic_bp                           False
# diastolic_bp                          False
# heart_rate                            False
# cholesterol_total                     False
# hdl_cholesterol                       False
# ldl_cholesterol                       False
# triglycerides                         False
# gender                                False
# ethnicity                             False
# education_level                       False
# income_level                          False
# smoking_status                        False
# employment_status                     False
# family_history_diabetes               False
# hypertension_history                  False
# cardiovascular_history                False
# diagnosed_diabetes                    False
# dtype: bool

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
df["gender"].unique()

df["ethnicity"].unique()

df["smoking_status"].unique()

df["education_level"].unique()
# Out:
# array(['Highschool', 'Graduate', 'Postgraduate', 'No formal'],
#       dtype=object)

# %%
df["gender"].value_counts()

df["smoking_status"].value_counts()
# Out:
# smoking_status
# Never      690
# Former     163
# Current    147
# Name: count, dtype: int64

# %%
df["bp_difference"] = (
    df["systolic_bp"] -
    df["diastolic_bp"]
)

# %%
df = df.dropna()

# %%
df.to_csv("data/cleaned_data.csv", index=False)
